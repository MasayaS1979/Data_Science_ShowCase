# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sqlite3 
from urllib import request 

data = pd.read_csv("vgsales.csv")
data.head(5)
cor = data.corr(numeric_only=True)["Global_Sales"].sort_values(ascending = False)
print(cor)
# Out:
# Global_Sales    1.000000
# NA_Sales        0.941047
# EU_Sales        0.902836
# Other_Sales     0.748331
# JP_Sales        0.611816
# Year           -0.074735
# Rank           -0.427407
# Name: Global_Sales, dtype: float64

# %%
#Simple Linear Regression 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
data.plot.scatter(x= "Global_Sales", y= "NA_Sales")
plt.show()

# %%
x_train,x_test, y_train,y_test = train_test_split(data.Global_Sales, data.NA_Sales)
plt.scatter(x_train, y_train, label = "training data", color = "r", alpha=.7)
plt.scatter(x_test, y_test, label = "test data", color = "g", alpha = .7)
plt.legend
plt.title = "Test vs Train data"
plt.show()

# %%
LR = LinearRegression()
LR.fit(x_train.values.reshape(-1,1), y_train.values)
prediction = LR.predict(x_test.values.reshape(-1, 1))
plt.plot(x_test,prediction, label="Linear Regression", color="b")
plt.scatter(x_test, y_test, label="Actual Test Data", color="g", alpha=0.7)
plt.legend()
plt.show()

# %%
LR.predict(np.array([[30]]))[0]
# Out:
# 14.808497466842494

# %%
LR.score(x_test.values.reshape(-1,1), y_test.values)
# Out:
# 0.8452182818256331
